# %%
import numpy as np

import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
height_weight = pd.read_csv("hw_200.csv")

# %%
height_weight = height_weight.drop(columns = "Index")

# %%
height_weight.head()
# Out:
#     Height(Inches)"   "Weight(Pounds)"
# 0             65.78             112.99
# 1             71.52             136.49
# 2             69.40             153.03
# 3             68.22             142.34
# 4             67.79             144.30

# %%
X = height_weight[[' Height(Inches)"']].values
y = height_weight[[' "Weight(Pounds)"']].values

# %%
height_weight.plot(x = 1, y = 2, style = "o")
plt.title("Height vs Weight")
plt.xlabel("Height (Inches)")
plt.ylabel("Weight (Pounds)")
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
# Out:
# [-106.40204971]

# %%
regressor.coef_
# Out:
# array([[3.44134897]])

# %%
y_pred = regressor.predict(X_test)

# %%
plt.scatter(X_test, y_test, color = "black")
plt.plot(X_test, y_pred, color = "blue")

# %%
import pickle

# %%
Regressor_Machine = open("model.pkl", "wb")
pickle.dump(regressor, Regressor_Machine)
Regressor_Machine.close()
